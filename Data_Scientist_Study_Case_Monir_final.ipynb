# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# check out if google dride mount suceessful 
# !ls "/content/drive/My Drive/Data Scientist Study Case "
# Out:
# ads-50k.json

# %%
# dataset file path in the google dride
filename = '/content/drive/My Drive/Data Scientist Study Case /ads-50k.json'

# %% [markdown]
# # Appropriate analyses on dataset

# %%
import pandas as pd
ads_df = pd.read_json(filename, lines=True)

# %%
# first 5 rows of the dataframe
ads_df.head()
# Out:
#          id                                              title  \
# 0  38915469                             Recruitment Consultant
# 1  38934839                     Computers Salesperson - Coburg
# 2  38946054                              Senior Developer | SA
# 3  38833950  Senior Commercial Property Manager | Leading T...
# 4  38856271               Technology Manager | Travel Industry
#
#                                             abstract  \
# 0  We are looking for someone to focus purely on ...
# 1  Passionate about exceptional customer service?...
# 2  Readifarians are known for discovering the lat...
# 3  ~ Rare opportunity for a Senior PM to step int...
# 4  Rare opportunity for an experienced Technology...
#
#                                              content  \
# 0  <HTML><p>Are you looking to join a thriving bu...
# 1  <HTML><p>&middot;&nbsp;&nbsp;Casual hours as r...
# 2  <HTML><p>Readify helps organizations innovate ...
# 3  <HTML><p><strong>WayPoint Recruitment&nbsp;</s...
# 4  <HTML>This is a key role within a market leadi...
#
#                                             metadata
# 0  {'standout': {'bullet1': 'Join a Sector that i...
# 1  {'additionalSalaryText': 'Attractive Commissio...
# 2  {'standout': {'bullet1': 'Design, develop, tes...
# 3  {'additionalSalaryText': '$140k + Car Park - C...
# 4  {'standout': {'bullet1': 'Lead overarching str...

# %%
ads_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        50000 non-null  int64
#  1   title     50000 non-null  object
#  2   abstract  50000 non-null  object
#  3   content   50000 non-null  object
#  4   metadata  50000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.9+ MB

# %%
ads_df.info
# Out:
# <bound method DataFrame.info of              id                                              title  \
# 0      38915469                             Recruitment Consultant
# 1      38934839                     Computers Salesperson - Coburg
# 2      38946054                              Senior Developer | SA
# 3      38833950  Senior Commercial Property Manager | Leading T...
# 4      38856271               Technology Manager | Travel Industry
# ...         ...                                                ...
# 49995  38836927                                       Data Analyst
# 49996  38894517                  Regional Coordinator - Goldfields
# 49997  38854483                              Warehouse Coordinator
# 49998  38905179            Expression of Interest - Civil Labourer
# 49999  38862684                               Provisioning Support
#
#                                                 abstract  \
# 0      We are looking for someone to focus purely on ...
# 1      Passionate about exceptional customer service?...
# 2      Readifarians are known for discovering the lat...
# 3      ~ Rare opportunity for a Senior PM to step int...
# 4      Rare opportunity for an experienced Technology...
# ...                                                  ...
# 49995  Data Analyst with Adobe Suite, Analytics and T...
# 49996  WAPHA > Health Industry - Planning and commiss...
# 49997  Temporary to permanent opportunity with a fant...
# 49998  Our clients are looking for an experienced Civ...
# 49999  At Teletrac Navman, we have a great opportunit...
#
#                                                  content  \
# 0      <HTML><p>Are you looking to join a thriving bu...
# 1      <HTML><p>&middot;&nbsp;&nbsp;Casual hours as r...
# 2      <HTML><p>Readify helps organizations innovate ...
# 3      <HTML><p><strong>WayPoint Recruitment&nbsp;</s...
# 4      <HTML>This is a key role within a market leadi...
# ...                                                  ...
# 49995  <HTML><strong>The Company</strong><br> I am wo...
# 49996  <HTML><p><strong>About Us</strong></p> <p>WA P...
# 49997  <HTML><div><em>Our client, a Global leader in ...
# 49998  <HTML><p><strong>Expression of Interest - Civi...
# 49999  <HTML><p>A fantastic opportunity for a tech sa...
#
#                                                 metadata
# 0      {'standout': {'bullet1': 'Join a Sector that i...
# 1      {'additionalSalaryText': 'Attractive Commissio...
# 2      {'standout': {'bullet1': 'Design, develop, tes...
# 3      {'additionalSalaryText': '$140k + Car Park - C...
# 4      {'standout': {'bullet1': 'Lead overarching str...
# ...                                                  ...
# 49995  {'classification': {'name': 'Information & Com...
# 49996  {'classification': {'name': 'Healthcare & Medi...
# 49997  {'classification': {'name': 'Manufacturing, Tr...
# 49998  {'classification': {'name': 'Trades & Services...
# 49999  {'standout': {'bullet1': 'Market leading telem...
#
# [50000 rows x 5 columns]>

# %% [markdown]
# # Extract all the class and sub-class from the classification and subclassification in the metadata

# %%
# Extract all the class and sub-class from the classification and subclassification in the metadata
metadata = []
metadata = ads_df['metadata']

# extract all the class and sub-class from the metadata
top_class = []
sub_class = []

for row in metadata:
    # get value from the key of the dictionary
    classification = row.get('classification')
    subClassification = row.get('subClassification')

    # find the fist key of the classification dictionary
    key1 = list(classification.keys())[0]
    key2 = list(subClassification.keys())[0]

    # get value from the key of the classification dictionary
    get_class = classification.get(key1)
    top_class.append(get_class)
    # get value from the key of the subClassification dictionary
    get_sub_class = subClassification.get(key2)
    sub_class.append(get_sub_class)

# %%
# find a list of unique class
unique_top_class = list(dict.fromkeys(top_class))

# %%
# Total number of unique classes
len(unique_top_class)
# Out:
# 30

# %%
# List of classes
print(unique_top_class)
# Out:
# ['Education & Training', 'Retail & Consumer Products', 'Information & Communication Technology', 'Real Estate & Property', 'Mining, Resources & Energy', 'Accounting', 'Community Services & Development', 'Manufacturing, Transport & Logistics', 'Hospitality & Tourism', 'Engineering', 'Sales', 'Marketing & Communications', 'Healthcare & Medical', 'Banking & Financial Services', 'Human Resources & Recruitment', 'Trades & Services', 'Construction', 'Advertising, Arts & Media', 'Administration & Office Support', 'Sport & Recreation', 'Call Centre & Customer Service', 'Legal', 'Consulting & Strategy', 'Government & Defence', 'Science & Technology', 'Design & Architecture', 'Farming, Animals & Conservation', 'CEO & General Management', 'Insurance & Superannuation', 'Self Employment']

# %%
# find and create a list of unique sub-class
unique_sub_class = list(dict.fromkeys(sub_class))

# %%
# Total number of unique sub-classes
len(unique_sub_class)
# Out:
# 337

# %%
# List of sub-classes
print(unique_sub_class)
# Out:
# ['Other', 'Retail Assistants', 'Consultants', 'Commercial Sales, Leasing & Property Mgmt', 'Management', 'Business Services & Corporate Advisory', 'Child Welfare, Youth & Family Services', 'Team Leaders/Supervisors', 'Chefs/Cooks', 'Sales Representatives/Consultants', 'Brand Management', 'Medical Imaging', 'Help Desk & IT Support', 'Warehousing, Storage & Distribution', 'Management - Vocational', 'Residential Sales', 'Nursing - Aged Care', 'Payroll', 'Financial Planning', 'Physiotherapy, OT & Rehabilitation', 'Account & Relationship Management', 'Travel Agents/Consultants', 'Recruitment - Agency', 'Marketing Assistants/Coordinators', 'Labourers', 'Foreperson/Supervisors', 'Plant & Machinery Operators', 'Media Strategy, Planning & Buying', 'Management Accounting & Budgeting', 'Developers/Programmers', 'Recruitment - Internal', 'Agency Account Management', 'Administrative Assistants', 'Nursing - Theatre & Recovery', 'Couriers, Drivers & Postal Services', 'Coaching & Instruction', 'Teaching - Vocational', 'Audit - Internal', 'Teaching - Secondary', 'Accounts Payable', 'Mining - Operations', 'Dental', 'Electricians', 'Customer Service - Call Centre', 'Personal Injury Law', 'Medical Administration', 'Strategy & Planning', 'Buying', 'Construction Law', 'Compliance & Risk', 'Psychology, Counselling & Social Work', 'Government - State', 'Dieticians', 'Residential Leasing & Property Management', 'PA, EA & Secretarial', 'Digital & Search Marketing', 'Sales - Pre & Post', 'Contracts Management', 'Plumbers', 'Security', 'Food Technology & Safety', 'New Business Development', 'Carpentry & Cabinet Making', 'Automotive Trades', 'Industrial & Employee Relations', 'Waiting Staff', 'Maintenance & Handyperson Services', 'Architects', 'Engineering - Hardware', 'Maintenance', 'Management - Area/Multi-site', 'Business/Systems Analysts', 'Body Corporate & Facilities Management', 'Project Management', 'Bar & Beverage Staff', 'Product Management & Development', 'Civil/Structural Engineering', 'Welders & Boilermakers', 'Mortgages', 'Teaching - Early Childhood', 'Organisational Development', 'Assembly & Process Work', 'Government - Federal', 'Nursing - Midwifery, Neo-Natal, SCN & NICU', 'Management - Department/Assistant', 'Sales', 'Receptionists', 'Quality Assurance & Control', 'Government - Local', 'Retail & Property Development', 'Road Transport', 'Surveying', 'Financial Managers & Controllers', 'Engineering - Network', 'General Practitioners', 'Architectural Drafting', 'Training & Development', 'Farm Management', 'Kitchen & Sandwich Hands', 'Financial Accounting & Reporting', 'Residents & Registrars', 'Field Engineering', 'Gardening & Landscaping', 'Fitters, Turners & Machinists', 'Internal Communications', 'Programme & Project Management', 'Employment Services', 'Production, Planning & Scheduling', 'Testing & Quality Assurance', 'Teaching - Primary', 'Engineering Drafting', 'Industrial Design', 'Pharmaceuticals & Medical Devices', 'Estimating', 'Networks & Systems Administration', 'Taxation', 'Veterinary Services & Animal Welfare', 'Hair & Beauty Services', 'Banking & Finance Law', 'Security Services', 'Accounts Officers/Clerks', 'Import/Export & Customs', 'Water & Waste Engineering', 'Speech Therapy', 'Sales - Inbound', 'Legal Secretaries', 'Analysts', 'Childcare & Outside School Hours Care', 'Environment & Sustainability Consulting', 'Government', 'Mining - Drill & Blast', 'Marketing Communications', 'Sales - Outbound', 'Medical Specialists', 'Engineering - Software', 'Accounts Receivable/Credit Control', 'Data Entry & Word Processing', 'Event Management', 'Aged & Disability Support', 'Management - Store', 'Analysis & Reporting', 'Audit - External', 'Nursing - General Medical & Surgical', 'Building Trades', 'Electrical/Electronic Engineering', 'Nursing - High Acuity', 'Building Services Engineering', 'Supervisors/Team Leaders', 'Law Clerks & Paralegals', 'Funds Management', 'Merchandisers', 'Technical Writing', 'Mining - Engineering & Maintenance ...

# %%
title = []
title = ads_df['title']
# Create a dataframe with ads title, class and subclass
job_class_df = pd.DataFrame(
    {
        'class': top_class,
        'sub_class': sub_class,
        'job_tile': title
    })

# %%
# Total number of ads with job title for each of the class
print(job_class_df['class'].value_counts(ascending=False))
# Out:
# Information & Communication Technology    5235
# Trades & Services                         4736
# Healthcare & Medical                      4599
# Manufacturing, Transport & Logistics      3213
# Accounting                                2859
# Administration & Office Support           2538
# Sales                                     2473
# Hospitality & Tourism                     2466
# Education & Training                      2337
# Construction                              2292
# Retail & Consumer Products                1932
# Engineering                               1747
# Government & Defence                      1710
# Mining, Resources & Energy                1434
# Community Services & Development          1350
# Marketing & Communications                1308
# Human Resources & Recruitment             1258
# Legal                                     1114
# Call Centre & Customer Service            1047
# Banking & Financial Services               990
# Real Estate & Property                     912
# Design & Architecture                      522
# Insurance & Superannuation                 390
# Science & Technology                       304
# Sport & Recreation                         274
# Consulting & Strategy                      261
# Advertising, Arts & Media                  258
# Farming, Animals & Conservation            250
# CEO & General Management                   179
# Self Employment                             12
# Name: class, dtype: int64

# %%
# Total number of ads with job title for each of the sub-class
print(job_class_df['sub_class'].value_counts(ascending=False))
# Out:
# Other                                   2688
# Management                              1618
# Administrative Assistants               1131
# Developers/Programmers                  1072
# Sales Representatives/Consultants       1038
#                                         ...
# Navy                                       3
# Oil & Gas - Exploration & Geoscience       3
# Nannies & Babysitters                      2
# Fund Administration                        1
# Regional Council                           1
# Name: sub_class, Length: 337, dtype: int64

# %%
from matplotlib import pyplot as plt

class_job_total = []
# total number of job ads based on class
for c in unique_top_class:
    each_class_total = (job_class_df['class'] == c).sum()
    class_job_total.append(each_class_total)

# Creating a simple bar chart to show total number of job ads based on class
plt.bar(unique_top_class, class_job_total)
plt.title('The total number of job ads based on class')
plt.xlabel('class = 30', fontsize=10)
plt.xticks(rotation='vertical', fontsize=8)
plt.ylabel('total number of jobs', fontsize=10)
plt.tight_layout()
plt.show()

# %%
sub_class_job_total = []
# total number of job ads based on sub class class
for sc in unique_sub_class:
    each_sub_class_total = (job_class_df['sub_class'] == sc).sum()
    sub_class_job_total.append(each_sub_class_total)

# Creating a simple bar chart to show total number of job ads based on sub-class
plt.bar(unique_sub_class[:33], sub_class_job_total[:33])
plt.title('The total number of job ads based on sub-class')
plt.xlabel('1st 33 sub_class', fontsize=10)
plt.xticks(rotation='vertical')
plt.ylabel('sub_class_job_total', fontsize=15)
plt.tight_layout()
plt.show()

# %%
sub_class_job_total = []
# total number of job ads based on sub class class
for sc in unique_sub_class:
    each_sub_class_total = (job_class_df['sub_class'] == sc).sum()
    sub_class_job_total.append(each_sub_class_total)

# Creating a simple bar chart to show total number of job ads based on sub-class
plt.bar(unique_sub_class[33:66], sub_class_job_total[33:66])
plt.title('The total number of job ads based on sub-class')
plt.xlabel('33 to 66 sub_class', fontsize=10)
plt.xticks(rotation='vertical')
plt.ylabel('sub_class_job_total', fontsize=15)
plt.tight_layout()
plt.show()

# %%
sub_class_job_total = []
# total number of job ads based on sub class class
for sc in unique_sub_class:
    each_sub_class_total = (job_class_df['sub_class'] == sc).sum()
    sub_class_job_total.append(each_sub_class_total)

# Creating a simple bar chart to show total number of job ads based on sub-class
plt.bar(unique_sub_class[66:100], sub_class_job_total[66:100])
plt.title('The total number of job ads based on sub-class')
plt.xlabel('66 to 100 sub_class', fontsize=10)
plt.xticks(rotation='vertical')
plt.ylabel('sub_class_job_total', fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Find all the sub-class based on a class and the ads title based on a sub-class
sample_class = 'Information & Communication Technology'
sample_sub_class = 'Consultants'

sub_class_for_sample_class = []
ads_role = []
# job ads based on sub class
for i in range(len(job_class_df['job_tile'])):
    if job_class_df['sub_class'].iloc[i] == sample_sub_class:
        role = job_class_df['job_tile'].iloc[i]
        ads_role.append(role)
    if job_class_df['class'].iloc[i] == sample_class:
        sc = job_class_df['sub_class'].iloc[i]
        sub_class_for_sample_class.append(sc)

# %%
# Number and the list of sub-class based on 'Information & Communication Technology' class
unique_sub_class_for_sample_class = list(dict.fromkeys(sub_class_for_sample_class))
print(len(unique_sub_class_for_sample_class))
print(unique_sub_class_for_sample_class)
# Out:
# 22
# ['Consultants', 'Management', 'Help Desk & IT Support', 'Developers/Programmers', 'Sales - Pre & Post', 'Security', 'Architects', 'Engineering - Hardware', 'Business/Systems Analysts', 'Engineering - Network', 'Programme & Project Management', 'Testing & Quality Assurance', 'Networks & Systems Administration', 'Engineering - Software', 'Product Management & Development', 'Technical Writing', 'Other', 'Database Development & Administration', 'Web Development & Production', 'Computer Operators', 'Telecommunications', 'Team Leaders']

# %%
# The ads title based on the 'Consultants' sub-class
unique_ads_role = list(dict.fromkeys(ads_role))
print(len(unique_ads_role))
print(unique_ads_role)
# Out:
# 246
# ['Senior Developer | SA', 'SAP CRM Technical Consultant', 'Technical Consultant - ServiceNow SA', 'SAP C4C Consultant', 'Principal Consultant', 'Business Consultant -SAP', 'Dynamics 365 CRM Technical Architect / Principal Consultant', 'Senior ERP Consultant - Pronto', 'Microsoft Dynamics (CRM) Functional Consultant', 'Data Scientist', 'Tableau Dashboard Designer', 'CRM Dynamics Technical and Functional Consultants', 'MS Dynamics CRM Functional Consultant', 'ICT Consultant - Project Unify (004195)', 'Oracle HCM Cloud Functional Consultant \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 - Permanent Role', 'Data Warehouse Developer', 'SEM/PPC Account Manager for Ad-Tech agency', 'Oracle CX Functional Consultant | Contract | North Melbourne', 'Senior Consultant - Data and Analytics', 'ERP Software Consultant', 'SAP MM Consultant', 'Cloud Consultant', 'Implementation Specialist', 'SAP SRM/MM Functional Consultant', 'ServiceNow Senior Consultant', 'ICT Contracts Manager', 'Oracle EPM/PBCS Expert', 'Infrastructure Integration Specialist ', 'Implementation Consultant - HRIS', 'IBM ECM Consultant', 'Senior Manager/ Consultant', 'Dynamics 365 Business Central Lead Consultant', 'SAP Integration Consultant  (PI/PO)- East Coast', 'Digital Business Adviser', 'Salesforce Marketing Cloud Consultant', 'Senior MS Dynamics 365 (CRM)  - up to $130,000 base', 'Software Implementation Consultant / Trainer', 'Junior SQL Developer', 'SAP S/4HANA Consultant', 'Application Support Consultant', 'Salesforce Functional Consultant', 'Senior Business Analyst', 'Senior Oracle HCM Implementation Consultant', 'Data Research Manager ', 'SAP EAM and Work Manager Consultant', 'Cloud Consultant - Azure', 'Snr BI Consultant go Team Lead - Finance / Accounting Experience Required!', 'ERP and NetSuite Analyst', 'Cloud Engineer DevOps', 'ITSCM Service Specialist', 'Microsoft Dynamics NAV/Business Central - Supply Chain Consultant', 'Service Delivery, But With A Twist!', 'Technical Consultant - Dunedin', 'SAP CRM Functional Consultants ', 'Systems Analyst - Major Govt Pgm - Brisbane - Contract', 'Data Management Specialist | Contract | Leading Australian brand', 'Change Manager', 'ServiceNow Tech Leads', 'Financial Application Consultant - Customer Facing Business and Technical Role', 'Technology Consulting Manager', 'PowerBI Consultant - 3 Month Contract - Financial Services ', 'Senior Data Warehouse Consultant', 'Data Engineer - AWS', 'Waste Management Consultant', 'SAP ABAP FICO Consultant', 'Senior Consultant, Technology Risk', 'Agile Consultant', 'Enterprise Architect - Infrastructure | Cloud | Virtualisation | Microsoft |', 'Computer Technician, Onsite & Instore - Part Time', 'Data Analyst', 'Solution Architect', 'Oracle Cloud Platform Solution Lead/Evangelist', 'Business Consultant - Financials', 'SharePoint Consultant ', 'OSI PI Consultant', 'Education Consultant - IT', 'ETL/Data Migration/Data Governance/BI and Reporting Analysts', 'Senior Hadoop Consultant', 'Automation Advisory : Senior Consulting Manager', 'Junior Consultant', 'SAP Client Relationship Manager', 'Analyst - Senior Analyst - Manager (Financial Services/Banking)', 'Data Governance Experts - MDM / Reference Data Model', 'SAP CRM Functional Consultant', 'SAP S/4HANA Technical Lead - $1450 p/d  - 14 Month Contract', 'BI Consultant ', 'Oracle HCM Cloud Consultant', 'Campaign Analyst', 'SharePoint Consultant (Office 365)', 'UX Designer', 'Scrum Master', 'eLearning Consultant', 'SAP EHS Consultant', 'Microsoft Dynamics 365 ERP Developer', 'Data Analytics Consultant', 'Senior ServiceNow Consultant - VIC', 'MSBI Consultants and Developers', 'SAP CRM Functional Consultant - Contract', 'TM1 Consultant', 'Salesforce Consultant', 'Dynamics 365 Business Analyst - Dandenong', 'SAP FICO S4HANA Consultant - 3 month - Christchurch, NZ', 'CA APM developer', 'AEM Forms - Tech Lead', 'Senior Consultant, IT Audit', 'Computer Scientist Consultant', 'Functional Consultant – SAP P2P MM', 'BMC Consultant', 'Senior ...

# %% [markdown]
# # Feature selection

# %%
# Feature selection from the datsset
# sample_class = 'Information & Communication Technology'
# sample_sub_class = 'Consultants'
abstract = []
content = []
abstract = ads_df['abstract']
content = ads_df['content']
feature_content = []
job_title = []

# Feature selection for a sample sub_class
for i in range(len(ads_df)):
    if sub_class[i] == sample_sub_class and top_class[i] == sample_class:
        feature_content.append(abstract[i])
        feature_content.append(content[i])
        job_title.append(title[i])

# join all the text from the feature_content list
feature_content = ''.join(feature_content)

# %% [markdown]
# # Initial approach: a embedding-based keyword extraction

# %% [markdown]
# ## Model 1: Generate embedding (word vectors) using Word2Vec

# %%
# Python program to generate embedding (word vectors) using Word2Vec

# importing necessary modules for embedding
# !pip install --upgrade gensim

import nltk
nltk.download('punkt')

# importing all necessary modules
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings

warnings.filterwarnings(action = 'ignore')

import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from gensim.scripts.glove2word2vec import glove2word2vec

import numpy
import multiprocessing
import re, string # using to remove regular expression, special characters in txt files
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.7/dist-packages (3.6.0)
# Collecting gensim
#   Downloading gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
#      |████████████████████████████████| 24.1 MB 1.4 MB/s
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from gensim) (1.21.6)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim) (6.0.0)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.2.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# text preprocessing to generate embedding (word vectors) using Word2Vec
text = feature_content
text = text.lower()
text = re.sub('\[.*?\]', '', text)
text = re.sub("\\W", " ", text)
text = re.sub('https?://\S+ |www\.\S+', '', text)
text = re.sub('<.*?>', '', text)
text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
text = re.sub('\n', '', text)
text = re.sub('\w*\d\w*', '', text)
# Replaces escape character with space
text = text.replace("\n", " ")

# %%
# using nltk.tokenize process sentence tokenize and tokenize the sentence into words
data = []
# iterate through each sentence in the file
for i in sent_tokenize(text):
    temp = []
    # tokenize the sentence into words
    for j in word_tokenize(i):
        temp.append(j.lower())
    data.append(temp)

# %%
# Create CBOW Word2Ve model
embedding_model = gensim.models.Word2Vec(data, min_count = 1, vector_size = 300, window = 10)

# %%
words = sorted(embedding_model.wv.key_to_index)

# %%
# sample_class = 'Information & Communication Technology'
# sample_sub_class = 'Consultants'
# Keywords for the Consultants subclass
print(words)
# Out:
# ['a', 'aaaand', 'aakanksha', 'aaliyah', 'ab', 'abap', 'abbyy', 'abilities', 'ability', 'able', 'abm', 'aboriginal', 'abound', 'about', 'above', 'abreast', 'abs', 'absence', 'absolute', 'absolutely', 'abstract', 'academic', 'academy', 'accelerate', 'acceleration', 'accept', 'acceptance', 'accepted', 'access', 'accessibility', 'accessible', 'accommodation', 'accomplished', 'accomplishing', 'accordance', 'according', 'accordingly', 'account', 'accountabilities', 'accountability', 'accountable', 'accountancy', 'accountants', 'accounting', 'accounts', 'accreditation', 'accredited', 'accuracy', 'accurate', 'accurately', 'accustomed', 'ace', 'achieve', 'achieved', 'achievement', 'achievements', 'achiever', 'achieves', 'achieving', 'acquire', 'acquiring', 'acquisition', 'acquisitions', 'across', 'act', 'acting', 'action', 'actionable', 'actions', 'activate', 'active', 'activehr', 'actively', 'activities', 'activity', 'acts', 'actually', 'actuarial', 'acumen', 'ad', 'adaps', 'adapt', 'adaptable', 'adapted', 'adapting', 'adaption', 'adaptive', 'add', 'added', 'addition', 'additional', 'additionally', 'address', 'addressed', 'addressing', 'adecco', 'adelaide', 'adept', 'adequate', 'adfs', 'adhere', 'adhered', 'adherence', 'adheres', 'adhering', 'admin', 'administer', 'administered', 'administering', 'administration', 'administrative', 'administrator', 'administrators', 'admired', 'adobe', 'adopt', 'adoption', 'advance', 'advanced', 'advancement', 'advancements', 'advances', 'advantage', 'advantageous', 'advantages', 'advantateous', 'advert', 'advertised', 'advertisement', 'advertising', 'advice', 'advise', 'adviser', 'advisers', 'advises', 'advising', 'advisor', 'advisors', 'advisory', 'advocate', 'aem', 'aerospace', 'af', 'affable', 'affecting', 'affiliated', 'afraid', 'africa', 'after', 'against', 'age', 'aged', 'agencies', 'agency', 'agenda', 'agendas', 'ages', 'aggregation', 'agile', 'agility', 'agnostic', 'ago', 'agree', 'agreed', 'agreement', 'agreements', 'agsva', 'ahead', 'ai', 'aid', 'aim', 'aimed', 'aims', 'aircraft', 'ajax', 'alana', 'ale', 'alex', 'alfred', 'alfreds', 'algorithms', 'alibaba', 'align', 'aligned', 'aligning', 'alignment', 'aligns', 'alike', 'all', 'alliance', 'allocation', 'allow', 'allowance', 'allowing', 'allows', 'alm', 'alone', 'along', 'alongside', 'already', 'also', 'alternative', 'alternatively', 'alternatives', 'alteryx', 'although', 'altitude', 'altogether', 'alv', 'always', 'am', 'amazing', 'amazon', 'ambassadors', 'ambition', 'ambitions', 'ambitious', 'america', 'americas', 'among', 'amount', 'amounts', 'amp', 'ampscript', 'ams', 'an', 'analyse', 'analyses', 'analysing', 'analysis', 'analyst', 'analystics', 'analysts', 'analytic', 'analytical', 'analytics', 'analyze', 'analyzer', 'analyzing', 'anaplan', 'anchor', 'and', 'andersen', 'andrew', 'android', 'angelina', 'angular', 'ankit', 'announce', 'annual', 'annually', 'annum', 'anomaly', 'another', 'ansible', 'answer', 'answered', 'answering', 'answers', 'ant', 'anthony', 'anthonyg', 'anticipate', 'anticipated', 'any', 'anyone', 'anypoint', 'anything', 'anywhere', 'anz', 'anzteam', 'apac', 'apache', 'apart', 'apex', 'api', 'apis', 'apj', 'apm', 'app', 'appealing', 'appeals', 'appearance', 'appetite', 'appexchange', 'apple', 'applicable', 'applicant', 'applicants', 'application', 'applications', 'applied', 'apply', 'applying', 'appoint', 'appointing', 'appointment', 'appraises', 'appreciate', 'appreciated', 'appreciation', 'approach', 'approaches', 'appropriate', 'appropriately', 'approvals', 'approved', 'approver', 'approx', 'approximately', 'apps', 'aptitude', 'ara', 'archimate', 'architect', 'architecting', 'architects', 'architectural', 'architecture', 'architectures', 'are', 'area', 'areas', 'aren', 'arena', 'argirellis', 'ariba', 'arise', 'arisen', 'arises', 'arm', 'armitage', 'arnold', 'aroop', 'around', 'arq', 'arqadians', 'arranged', 'arrangements', 'array', 'art', 'artefacts', 'articulate', 'articulating', 'artificial', 'artistic', 'arzel', ' ...

# %% [markdown]
# ## Initial approach: a embedding-based keyword extraction
# ### Model 2: Generate keywords and keyphases using KeyBERT and Keyphrase_vectorizers

# %%
# !pip install keybert
# !pip install keyphrase_vectorizers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keybert
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.8 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.21.6)
# Collecting rich>=10.4.0
#   Downloading rich-12.4.4-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 17.2 MB/s
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (4.2.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.9 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (2.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 47.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 50.7 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.9 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 31.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 16.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (4.11.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21332 sha256=bebd18b789dc393f911d89fa8d46a76487a66398ab5d66f7cd1ed833ebf803e7
#   Stored in directory: /root/.cache/pip/wheels/8e/95/c5/f5ceed2a9f9e80bc1a706a10a6fb03d726df7a3dd11800a58b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=4bdb8d57103ae6eeb0018acea30de391181652bc22c8bba8a96859423ec3d802
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built keybert sentence-transformers
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed commonmark-0.9.1 huggingface-hub-0.7.0 keybert-0.5.1 pyyaml-6.0 rich-12.4.4 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.19.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keyphrase_vectorizers
#   Downloading keyphrase_vectorizers-0.0.8-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keyphrase_vectorizers) (1.21.6)
# Collecting psutil>=5.8.0
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 10.1 MB/s
# Collecting nltk>=3.6.1
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 32.7 MB/s
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.7/dist-packages (from keyphrase_vectorizers) (1.0.2)
# Collecting spacy>=3.0.1
#   Downloading spacy-3.3.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 43.3 MB/s
# Collecting scipy>=1.7.3
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.1->keyphrase_vectorizers) (7.1.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.6.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (749 kB)
#      |████████████████████████████████| 749 kB 60.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.1->keyphrase_vectorizers) (4.64.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk>=3.6.1->keyphrase_vectorizers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0->keyphrase_vectorizers) (3.1.0)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 43.1 MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (0.9.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (1.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (3.0.6)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.6 MB/s
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 38.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (57.4.0)
# Collecting typing-extensions<4.2.0,>=3.7.4
#   Downloading typing_extensions-4.1.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (2.23.0)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 58.9 MB/s
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (21.3)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 46.9 MB/s
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.1->keyphrase_vectorizers) (0.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.1->keyphrase_vectorizers) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.1->keyphrase_vectorizers) (3.0.9)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 6.6 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->keyphrase_vectorizers) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->keyphrase_vectorizers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->keyphrase_vectorizers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0.1->keyphrase_vectorizers) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.1->keyphrase_vectorizers) (2.0.1)
# Installing collected packages: typing-extensions, catalogue, typer, srsly, smart-open, pydantic, thinc, spacy-loggers, spacy-legacy, scipy, regex, pathy, langcodes, spacy, psutil, nltk, keyphrase-vectorizers
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 6.0.0
#     Uninstalling smart-open-6.0.0:
#       Successfully uninstalled smart-open-6.0.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed catalogue-2.0.7 keyphrase-vectorizers-0.0.8 langcodes-3.3.0 nltk-3.7 pathy-0.6.1 psutil-5.9.1 pydantic-1.8.2 regex-2022.6.2 scipy-1.7.3 smart-open-5.2.1 spacy-3.3.1 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 thinc-8.0.17 typer-0.4.1 typing-extensions-4.1.1

# %%
from keyphrase_vectorizers import KeyphraseCountVectorizer
from keybert import KeyBERT

# %%
# keywords generate using the KeyBERT model
kw_model = KeyBERT()
keywords = kw_model.extract_keywords(text)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# keywords generate using the KeyBERT model
key_words = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words=None)

# %%
# sample_class = 'Information & Communication Technology'
# sample_sub_class = 'Consultants'
# Keywords for the Consultants subclass
print(key_words)
# Out:
# [('consultant', 0.4424), ('readify', 0.4416), ('clients', 0.4391), ('stakeholders', 0.4379), ('enterprise', 0.4146)]

# %%
# key-phrases generate using the KeyBERT model
key_phrases = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), stop_words=None)

# %%
# sample_class = 'Information & Communication Technology'
# sample_sub_class = 'Consultants'
# key_phrases for the Consultants subclass
print(key_phrases)
# Out:
# [('consultant br', 0.5472), ('br consultant', 0.539), ('stakeholders br', 0.5329), ('readify embraces', 0.525), ('consulting br', 0.5222)]

# %% [markdown]
# # Final approach: Role-Based Skill & Experience Extraction

# %% [markdown]
# ### Role-Based Feature Group Selection
# Sample job titles :
# 'Systems Engineer', 'Data Engineer', 'Data Scientist', 'Data Analyst', 'Solution Architect', 'Cloud Engineer', 'AWS Cloud Engineer'

# %%
# Python program to generate Role-Based Feature Group Selection

# sample job titles 
sample_job_title = ['Systems Engineer', 'Data Engineer', 'Data Scientist', 'Data Analyst', 'Solution Architect', 'Cloud Engineer', 'AWS Cloud Engineer']
all_feature_text = []

for job in sample_job_title:
  feature_text = []
  for i in range(len(ads_df)):
      # Match ads title with sample_job_title
      match = re.search(job, title[i])
      if match:
          feature_text.append(abstract[i])
          feature_text.append(content[i])
  # join all the text from the list of abstract
  joined_feature_text = ''.join(feature_text)
  all_feature_text.append(joined_feature_text)

# %% [markdown]
# ### Rule-Based Features Extraction
# List of given key words to get the interested feature text from the data:
# 'Experience', 'EXPERIENCE REQUIRED', 'experience required', 'experience is desirable',
#                   'experience is highly desirable', 'experienced', 'Extensive experience in', 'Experience with',
#                   'hands-on experience', 'Strong experience with', 'Strong experience in', 'Skills',
#                   'Skills required', 'Skills needed', 'technical skills', 'ability', 'expertise', 'expect',
#                   'desirable', 'passion', 'passionate', 'highly', 'desirable'

# %%
# list of given key words to get the interested feature text from the data
key_experience = ['Experience', 'EXPERIENCE REQUIRED', 'experience required', 'experience is desirable',
                  'experience is highly desirable', 'experienced', 'Extensive experience in', 'Experience with',
                  'hands-on experience', 'Strong experience with', 'Strong experience in', 'Skills',
                  'Skills required', 'Skills needed', 'technical skills', 'ability', 'expertise', 'expect',
                  'desirable', 'passion', 'passionate', 'highly', 'desirable']

# %%
all_key_feature_text = []
for text in all_feature_text:
  key_feature_text = []
   # splitlines of the text from the abstract and content for each of the sample job titles
  list_of_feature_text = text.splitlines()
  # capture the lines that contains any of the key-experiences from key_experiences list
  for line in list_of_feature_text:
      for item in key_experience:
          if item in line:
              if line not in key_feature_text:
                  key_feature_text.append(line)
  key_feature_text = ''.join(key_feature_text)
  all_key_feature_text.append(key_feature_text)

# %%
# !pip install yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 4.8 MB/s
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 17.7 MB/s
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake) (1.21.6)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake) (2.6.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake) (2022.6.2)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74002 sha256=f016a7c1d9c50c3819c7cb03127169a94d37794e9c9b86b379598ed28db06137
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8

# %%
import yake
kw_extractor = yake.KeywordExtractor()
keywords_for_role = []
language = "en"
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 50
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
for text in all_key_feature_text:
  keywords = custom_kw_extractor.extract_keywords(text)
  keywords_for_role.append(keywords)

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[0])
print('Key Skill & Experience Extracted:')
keywords_for_role[0]
# Out:
# Role: Systems Engineer
# Key Skill & Experience Extracted:
# [('Senior Systems Engineer', 6.516579129001047e-06),
#  ('Systems Engineer', 8.15159398501971e-06),
#  ('Control Systems Engineer', 1.3247806128361187e-05),
#  ('Systems Engineering experience', 3.407895436379414e-05),
#  ('systems engineering', 4.378369879378785e-05),
#  ('strong', 5.750434703338474e-05),
#  ('systems engineering services', 6.607996170009682e-05),
#  ('systems', 6.632024788285902e-05),
#  ('Systems Engineer role', 6.709800162796907e-05),
#  ('experienced Systems Engineer', 9.353817899002946e-05),
#  ('strong system engineer', 9.514030874782874e-05),
#  ('Linux Systems Engineer', 0.00010199419440058238),
#  ('Security Systems Engineer', 0.00012356466102851033),
#  ('Senior Systems', 0.00013950077482547906),
#  ('experience', 0.00014573733424951495),
#  ('control systems', 0.00015601105008968908),
#  ('HTML', 0.0001578435395371145),
#  ('Level Systems Engineer', 0.0001640166484468646),
#  ('Control system design', 0.0001730840707047124),
#  ('Microsoft System Centre', 0.00017394576276006141),
#  ('Systems Engineer Senior', 0.00018246421561202934),
#  ('Wintel Systems Engineer', 0.00018646861159216774),
#  ('Systems Engineer Australian', 0.00018796625871658087),
#  ('Systems Engineering Support', 0.0002059490142321434),
#  ('Engineer', 0.00020621982552705088),
#  ('Systems Design Engineer', 0.0002142485872537247),
#  ('system', 0.00021908550852337564),
#  ('Azure Systems Engineer', 0.0002213180080034738),
#  ('Microsoft Windows Server', 0.00022554593988245548),
#  ('Systems Engineer required', 0.0002329500336770767),
#  ('System Engineer team', 0.00023684279250951425),
#  ('engineering systems development', 0.00024328856299017505),
#  ('Senior Control Systems', 0.00024498360043280617),
#  ('control systems engineering', 0.00024817195625922333),
#  ('systems engineering knowledge', 0.0002499660153530614),
#  ('experience Senior Systems', 0.0002511638294901084),
#  ('Citrix Systems Engineer', 0.00026240246902295715),
#  ('systems engineer technical', 0.0002795317544189878),
#  ('Networking Systems Engineer', 0.00029166588677199127),
#  ('AWS Systems Engineer', 0.00031883670400630873),
#  ('control systems experience', 0.0003284465500797973),
#  ('providing systems engineering', 0.0003445580104435615),
#  ('Strong experience', 0.0003729795738505471),
#  ('engineering', 0.0004079113731695141),
#  ('support Windows Systems', 0.00041406728522787306),
#  ('Windows Server', 0.00042658238857285776),
#  ('systems engineering design', 0.0004456060603883102),
#  ('system design', 0.0004463139536247482),
#  ('infrastructure system engineering', 0.00044922778562935293),
#  ('Automation Systems Engineer', 0.0004556918223161454)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[1])
print('Key Skill & Experience Extracted:')
keywords_for_role[1]
# Out:
# Role: Data Engineer
# Key Skill & Experience Extracted:
# [('data engineer', 6.243151915370954e-05),
#  ('Data', 9.207410436628852e-05),
#  ('Big Data Engineer', 0.0001042859152646172),
#  ('experience Data Engineers', 0.00014128417913231926),
#  ('big data', 0.00016326292727439953),
#  ('strong', 0.0003085096748352235),
#  ('experience', 0.0003353919510036092),
#  ('Azure Data', 0.000368920686505402),
#  ('data engineering', 0.00037741812666890635),
#  ('Senior Data Engineer', 0.00040118971986748624),
#  ('Azure Data Factory', 0.0004213972501033649),
#  ('Azure Data Engineer', 0.0004588201497202506),
#  ('AWS Data Engineer', 0.0005440804231760459),
#  ('SQL Data Engineer', 0.0005512688581466508),
#  ('data pipelines', 0.0005593079373776719),
#  ('Azure Data Lake', 0.000595740939678325),
#  ('Experience building data', 0.0006670735891422364),
#  ('HTML', 0.0007244782859000151),
#  ('Data Engineer required', 0.0007285060668680735),
#  ('strong SQL skills', 0.0008249169475456424),
#  ('highly experience Data', 0.000861680544969296),
#  ('Hadoop Data Engineer', 0.0008846303529293942),
#  ('Big Data Platforms', 0.0009402950959945354),
#  ('building data pipelines', 0.0009894373562102444),
#  ('Experience preparing data', 0.0010259455420241247),
#  ('experience data', 0.0010640111135983674),
#  ('big data development', 0.001070519050529434),
#  ('data engineering roles', 0.0011394594188605881),
#  ('data analysis data', 0.001182033839061247),
#  ('ideal Data Engineer', 0.0012144527228351578),
#  ('big data technologies', 0.001240432330890923),
#  ('skills Azure Data', 0.0012598258965932693),
#  ('Data Analytics', 0.0012722263359937573),
#  ('data science', 0.0013074015095857875),
#  ('engineer', 0.0013085575718632387),
#  ('data lakes experience', 0.001446303558111429),
#  ('Aspiring Data Engineer', 0.0014902808058684916),
#  ('Big Data Developer', 0.0016366693600489168),
#  ('Microsoft Azure data', 0.0016429057151821013),
#  ('Data Engineer Consultant', 0.0016817673296150664),
#  ('Certified Data Engineer', 0.0016998147708728966),
#  ('Big Data Skills', 0.0017281021285234302),
#  ('talented Data Engineer', 0.0017882929030493039),
#  ('Data warehousing', 0.0018046449857818548),
#  ('big data tools', 0.0019317910564946663),
#  ('Experience working', 0.001973158317296993),
#  ('general data engineer', 0.0019883979735356994),
#  ('Azure data platform', 0.002044741892443695),
#  ('building data', 0.0020530489866795636),
#  ('Years Data Engineer', 0.0020536362529058098)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[2])
print('Key Skill & Experience Extracted:')
keywords_for_role[2]
# Out:
# Role: Data Scientist
# Key Skill & Experience Extracted:
# [('Data Scientist', 0.00011084665817592655),
#  ('data science', 0.0001357227153275758),
#  ('Surveillance Data Scientist', 0.00021603721232467464),
#  ('Data', 0.000241472240019418),
#  ('Senior Data Scientist', 0.0002445653849762033),
#  ('data science team', 0.000326842985678166),
#  ('strong', 0.00037479910870570436),
#  ('strong data science', 0.0004261555985702572),
#  ('experienced Data Scientist', 0.0006348984501104978),
#  ('strong Data Scientist', 0.0006944098227644423),
#  ('Data Scientist role', 0.0007383106275295846),
#  ('machine learning', 0.0007494678469506343),
#  ('data science projects', 0.0007948783516510005),
#  ('Lead Data Scientist', 0.0008114792271637028),
#  ('Market Surveillance Data', 0.0009179842926729837),
#  ('HTML', 0.0010969307717906612),
#  ('Strong data analytics', 0.0011863220695486085),
#  ('Experience', 0.0012785811188775309),
#  ('Data Scientist skill', 0.0013595749284683752),
#  ('Data Scientist Consultant', 0.0013685783336777992),
#  ('Big Data', 0.001607693537366961),
#  ('strong Data', 0.0017386810891400132),
#  ('Research Data Scientist', 0.001739865855039613),
#  ('Science', 0.0018479832632668797),
#  ('Scientist', 0.0019260112366537546),
#  ('Data Science Lead', 0.0019984854325141737),
#  ('Data Science capability', 0.0020208176431235634),
#  ('data science capabilities', 0.002065213786284052),
#  ('Surveillance Data', 0.002172434736819532),
#  ('global data science', 0.0021896534443362646),
#  ('customer data science', 0.0022194885730918057),
#  ('Senior Data', 0.002411689928942762),
#  ('Data Scientists reporting', 0.002452961539215849),
#  ('drive data science', 0.0027161956995876996),
#  ('Advanced data science', 0.002775930179089055),
#  ('Python', 0.002864015092961556),
#  ('data science tools', 0.0029024486955718386),
#  ('Computer Science', 0.00292534495889668),
#  ('analytics', 0.0029625296119856807),
#  ('related data science', 0.003061409302107784),
#  ('Data Scientist candidate', 0.0031381165443070294),
#  ('support data science', 0.0031705869996337373),
#  ('passionate Data Scientist', 0.0032821178769532468),
#  ('Data Scientists required', 0.003305009908890538),
#  ('data science languages', 0.003352261106450727),
#  ('hands-on Data Scientist', 0.0033634462240974767),
#  ('Data Science background', 0.003406882567968774),
#  ('develop data science', 0.0034359479195435615),
#  ('learning', 0.003436971932543291),
#  ('team', 0.0034432772641755315)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[3])
print('Key Skill & Experience Extracted:')
keywords_for_role[3]
# Out:
# Role: Data Analyst
# Key Skill & Experience Extracted:
# [('Senior Data Analyst', 6.45772824965955e-06),
#  ('Data Analyst', 8.567001630493522e-06),
#  ('Data', 4.1838495795259646e-05),
#  ('Data Analyst role', 4.764936445995111e-05),
#  ('experienced Data Analyst', 4.8106320756321016e-05),
#  ('strong', 7.899109873588151e-05),
#  ('Data Analyst required', 9.222978756929499e-05),
#  ('Data Analyst experience', 0.00010255840355520453),
#  ('Data Analyst designs', 0.00010834330281080673),
#  ('data analysis', 0.00012742302459431868),
#  ('Data Analyst SQL', 0.00013830984842533948),
#  ('Senior Data', 0.0001422684480747525),
#  ('HTML', 0.00017307726873826485),
#  ('Data Analyst working', 0.00017557645501004577),
#  ('data analytics experience', 0.00019810764100332325),
#  ('analyst', 0.0002059909070459306),
#  ('experience', 0.00022260709313866634),
#  ('Data Analyst position', 0.0002241585274105285),
#  ('Master Data Analyst', 0.0002342098418256181),
#  ('CRM Data Analyst', 0.00024232793751542843),
#  ('Business Data Analyst', 0.00024286717491762768),
#  ('strong data analysis', 0.0002995192454408706),
#  ('Data Analytics', 0.00030417416605114375),
#  ('Statistical Data Analyst', 0.0003108099667381788),
#  ('Lead Data Analyst', 0.00031802599949122453),
#  ('Assessment Data Analyst', 0.00032027716267993544),
#  ('Master Data experience', 0.000365792761994585),
#  ('Master Data', 0.0003777220941075652),
#  ('Demonstrated experience', 0.0004302766219844931),
#  ('Assistant Data Analyst', 0.0004441579578439204),
#  ('Data Analytics role', 0.00046508373799327536),
#  ('Strong business analysis', 0.00047665623079252083),
#  ('experience data analysis', 0.0005081949892622306),
#  ('Behaviour Data Analyst', 0.0005094413607256348),
#  ('Junior Data Analyst', 0.000515528517723441),
#  ('data analysis role', 0.00059894548799192),
#  ('data migration', 0.0006168652692288952),
#  ('data analysis skills', 0.0006324635131335608),
#  ('Data migration project', 0.0006374149631295463),
#  ('Experience working', 0.0006555270818280998),
#  ('Undertake data analysis', 0.0006848974112022605),
#  ('Analyst role', 0.0006866066061731876),
#  ('Strong data', 0.0006874537705510171),
#  ('data analyst background', 0.0007468990800258239),
#  ('successful Data Analyst', 0.0007547898995515606),
#  ('Inventory Data Analyst', 0.0007707787937258893),
#  ('senior analytics experience', 0.0007715537184028349),
#  ('Data Analyst Scientist', 0.0007981339526983815),
#  ('Data Analyst delivering', 0.000805309165966935),
#  ('business', 0.000816132181414221)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[4])
print('Key Skill & Experience Extracted:')
keywords_for_role[4]
# Out:
# Role: Solution Architect
# Key Skill & Experience Extracted:
# [('Solution Architect', 1.8495362860013126e-05),
#  ('Solution Architecture experience', 4.5247190604706235e-05),
#  ('Senior Solution Architect', 7.778528224243739e-05),
#  ('strong', 8.382644733246089e-05),
#  ('Solution Architecture', 8.519561881607866e-05),
#  ('experienced Solution Architect', 8.549173675650205e-05),
#  ('Digital Solution Architect', 0.00014008446417691756),
#  ('Solution', 0.00015612235205985527),
#  ('NET Solution Architect', 0.00017426843543730854),
#  ('experience', 0.00019450535231880465),
#  ('Salesforce Solution Architect', 0.00020113540556251558),
#  ('Solution Architect role', 0.00020897710394987852),
#  ('Cybersecurity Solution Architect', 0.00023176154297509577),
#  ('Security Solutions Architect', 0.00023928004837520908),
#  ('HTML', 0.0002492714533118298),
#  ('Application Solution Architect', 0.00025137772027237717),
#  ('solutions', 0.00025523373286189823),
#  ('Principal Solution Architect', 0.00026081487143795115),
#  ('Infrastructure Solution Architect', 0.00027676874321334286),
#  ('provide solution Architecture', 0.00030022944471540074),
#  ('Architect', 0.0003107287884108481),
#  ('Solution Architect experienced', 0.00031346970144050754),
#  ('design technology solutions', 0.0003508388547998127),
#  ('Cloud Solution Architect', 0.0003830158845834305),
#  ('Business Solution Architect', 0.00041544829557129033),
#  ('Architect solutions role', 0.00041795420789975704),
#  ('Experience working', 0.0004230742505004609),
#  ('Solution Architect required', 0.0004431270545370787),
#  ('solution design', 0.00046257302029205133),
#  ('solution Architecture design', 0.00046928136747275616),
#  ('proven Solution Architect', 0.00047193348634283234),
#  ('Azure Solution Architect', 0.00047622388696611325),
#  ('Architecture', 0.0004914571405528266),
#  ('Management Solution Architect', 0.0005506296851864838),
#  ('Lead Solution Architects', 0.0005602164926738606),
#  ('Client Solutions Architect', 0.0005653029330363846),
#  ('technology solutions', 0.0006164169047944752),
#  ('Solution Architect position', 0.0006234668920360125),
#  ('deliver solution architecture', 0.000760655441978212),
#  ('Architecture experience', 0.00076899430526093),
#  ('Solution Architect opportunity', 0.0007886717099341167),
#  ('define technology solutions', 0.0007941682712133935),
#  ('business', 0.0007946124413786351),
#  ('Solution Architect gained', 0.0007975655798798463),
#  ('Enterprise Architecture', 0.0008203132850853586),
#  ('SAP Solution Architect', 0.0008298946255391938),
#  ('Strong architecture skills', 0.0008388319149376013),
#  ('demonstrated experience working', 0.0008605906282007826),
#  ('solution architecture role', 0.0009030283853244686),
#  ('Strong experience', 0.0009095125374521607)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[5])
print('Key Skill & Experience Extracted:')
keywords_for_role[5]
# Out:
# Role: Cloud Engineer
# Key Skill & Experience Extracted:
# [('Cloud Engineer', 0.00035112438569302057),
#  ('AWS Cloud Engineer', 0.0003619771061244945),
#  ('Cloud Engineer Experience', 0.0004535945730700584),
#  ('strong', 0.0006994695623638387),
#  ('experienced cloud engineer', 0.0008228580025388423),
#  ('Cloud', 0.0008940560583972683),
#  ('Senior Cloud Engineer', 0.0009718362091374966),
#  ('experience', 0.0009863485792259501),
#  ('successful Cloud Engineer', 0.0012099642350054006),
#  ('AWS cloud', 0.0013062541668632664),
#  ('Azure Cloud Platform', 0.0014460992878662837),
#  ('AWS cloud platforms', 0.0014803467479846755),
#  ('Lead Cloud Engineer', 0.0015375155254644115),
#  ('Cloud Engineer Responsibilities', 0.0015844962891029177),
#  ('developing AWS cloud', 0.0023654532144775343),
#  ('strong experience', 0.002419495538388568),
#  ('HTML', 0.002566388275420793),
#  ('Cloud Engineer works', 0.002839288835558993),
#  ('Engineer Experience Requirements', 0.0028427976339405843),
#  ('AZURE', 0.002847519930162594),
#  ('AWS', 0.002912250222364428),
#  ('Cloud services', 0.0030038937928170747),
#  ('Lead AWS Cloud', 0.0030800953384243065),
#  ('AWS Cloud Engineering', 0.003333517497920727),
#  ('Systems Cloud Engineer', 0.003505458376889355),
#  ('Azure Infrastructure Engineer', 0.0035631367165949736),
#  ('Engineer', 0.003876879431306059),
#  ('cloud migration experience', 0.003965213488435546),
#  ('Senior Azure Engineer', 0.0043273417614228165),
#  ('Azure Cloud', 0.0044693623113600004),
#  ('cloud engineering technical', 0.004576112956074064),
#  ('Azure SQL', 0.004676063592647608),
#  ('Azure SQL Databases', 0.004720567919500451),
#  ('Senior Cloud', 0.004814658210301158),
#  ('Cloud engineering', 0.005471962221856482),
#  ('experience working', 0.00554857409280291),
#  ('Engineer Experience', 0.005743805694233296),
#  ('cloud platform', 0.006098953449122183),
#  ('experienced cloud', 0.0065955240762752615),
#  ('development', 0.00690528076212952),
#  ('services', 0.0070458345050597075),
#  ('Infrastructure', 0.007189115419550595),
#  ('AWS services', 0.0075543337842106885),
#  ('specialist Cloud services', 0.007576930320323834),
#  ('Cloud experience', 0.007653513356938536),
#  ('team', 0.00921947290337432),
#  ('Skills', 0.009372595139308104),
#  ('role', 0.00945052232749755),
#  ('large-scale AWS cloud', 0.009571328017220349),
#  ('Server Cloud engineering', 0.00972929855643357)]

# %%
# Role-Based Skill & Experience Extraction 
print('Role:', sample_job_title[6])
print('Key Skill & Experience Extracted:')
keywords_for_role[6]
# Out:
# Role: AWS Cloud Engineer
# Key Skill & Experience Extracted:
# [('Experience configuring alerting', 0.00015203996106132994),
#  ('AWS environment driving', 0.00028747716930653007),
#  ('whilst maintaining service', 0.0003966639316380047),
#  ('maintaining service levels', 0.0003966639316380047),
#  ('environment driving efficiencies', 0.000415667802868242),
#  ('cost savings whilst', 0.0004893277259951172),
#  ('savings whilst maintaining', 0.0004893277259951172),
#  ('source code management', 0.0004893277259951172),
#  ('code management tools', 0.0004893277259951172),
#  ('Java and JSON', 0.0016461448589913726),
#  ('Experience configuring', 0.0019256793519612586),
#  ('Amazon DynamoDB', 0.00270974407591417),
#  ('Bitbucket or equivalent', 0.00270974407591417),
#  ('Web Services', 0.002951597923337168),
#  ('Experience with programming', 0.003106715422544906),
#  ('Experience with source', 0.003106715422544906),
#  ('Identify and exploit', 0.0031859807405051096),
#  ('AWS environment', 0.0036357441031001714),
#  ('telemetry for Web', 0.0036357441031001714),
#  ('Experience with SQL', 0.004377420604514721),
#  ('service delivery', 0.005010722896785802),
#  ('maintaining service', 0.005010722896785802),
#  ('service levels', 0.005010722896785802),
#  ('driving efficiencies', 0.005249705736226226),
#  ('customer expectations.', 0.005249705736226226),
#  ('NoSQL DBs', 0.005249705736226226),
#  ('infrastructure automation', 0.006128076535352336),
#  ('Experience', 0.006133433289333635),
#  ('exploit opportunities', 0.00617508895422043),
#  ('opportunities to improve', 0.00617508895422043),
#  ('improve solutions', 0.00617508895422043),
#  ('environment driving', 0.00617508895422043),
#  ('cost savings', 0.00617508895422043),
#  ('savings whilst', 0.00617508895422043),
#  ('whilst maintaining', 0.00617508895422043),
#  ('levels and customer', 0.00617508895422043),
#  ('programming and infrastructure', 0.00617508895422043),
#  ('configuring alerting', 0.00617508895422043),
#  ('alerting and telemetry', 0.00617508895422043),
#  ('source code', 0.00617508895422043),
#  ('code management', 0.00617508895422043),
#  ('management tools', 0.00617508895422043),
#  ('SQL and MongoDB', 0.008301922756580479),
#  ('automation and cost', 0.01605906870000864),
#  ('solutions and service', 0.019799832990162625),
#  ('SQL', 0.02290056306104281),
#  ('service', 0.03182107639702342),
#  ('Python', 0.03499654559936121),
#  ('Perl', 0.03499654559936121),
#  ('PHP', 0.03499654559936121)]
